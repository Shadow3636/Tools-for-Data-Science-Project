# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Austin**
# I'm currently a Soldier with the United States Army. My goal is to work in data science at the end of my contract.

# %% [markdown]
# *Data science interests me due to it's amount of possibilities. I've always been drawn to mathematics, and have always had an affinity for computers. I really admire how data science has a place in every industry, allowing data scienctists to do not only what they are good at, but also in a field they are passionate about. I hope to work in the construction industry/ real estate industry, helping analyze property trends.*

# %% [markdown]
# ### The code below is simply to print a small thanks for reading my notebook! :)

# %%
print("Thank you for reading my notebook!")
# Out:
# Thank you for reading my notebook!

# %% [markdown]
# ***

# %% [markdown]
# - I'm enjoying working in IBM.

# %% [markdown]
# - I'm excited to start working with actual data.

# %% [markdown]
# > It is not our part to master all the tides of the world, but to do what is in us for the succour of those years wherein we are set, uprooting the evil in the fields that we know, so that those who live after may have clean earth to till. What weather they shall have is not ours to rule.
# >
# > J.R.R. Tolkien
